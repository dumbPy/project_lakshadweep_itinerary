# %%
from selenium.webdriver import Firefox
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options

# %%
import PIL
from PIL import Image
from pytesseract import image_to_string
import pytesseract
import numpy as np, matplotlib.pyplot as plt, pandas as pd

# %% [markdown]
# ### Load Firefox and get the Lakport Schedule page

# %%
opts = Options()
opts.headless=True
browser = Firefox(options=opts)
browser.get('http://lakport.nic.in/ship_online_programme.aspx')

# %% [markdown]
# ### Select All Passenger Ships option

# %%
#Select All Passenger Ships in drop down selection
ship_selector=Select(browser.find_element_by_id("ContentPlaceHolder1_ship_dlist"))
ship_selector.select_by_visible_text("All Passenger Ships")
ship_selector=Select(browser.find_element_by_id("ContentPlaceHolder1_ship_dlist"))
print(ship_selector.all_selected_options[0].text)
# Out:
# All Passenger Ships

# %% [markdown]
# ### Defining all required methods to extract and solve captcha

# %%
def extract_capcha(browser):
    """Extract the captcha from browser and return
    """
    img=browser.find_element_by_css_selector('img')
    import os, random
    os.makedirs('captcha', exist_ok=True) # Serialize the captchas
    captchas=[int(filename.split('.')[0].split('_')[1]) for filename 
              in os.listdir('captcha') if 'cap' in filename]
    # New name = old name + 1
    if len(captchas)==0: captchas=[-1]
    cap_name = 'captcha/cap_'+ str(max(captchas)+1) +'.png'
    img.screenshot(cap_name)
    return Image.open(cap_name)

def display_captcha(browser):
    plt.imshow(extract_capcha(browser))
    print("OCR Prediction: ", image_to_string(extract_capcha(browser)))
    plt.show()

# %%
def solve_captcha(browser):
    """Solve the captcha using teserract and press Enter/Return
    """
    captcha_inp=browser.find_element_by_id('ContentPlaceHolder1_txtimage')
    captcha_inp.clear()
    captcha_inp.send_keys(image_to_string(extract_capcha(browser)))
    captcha_inp.send_keys(Keys.RETURN)

# %%
def solve_captcha_again(browser, display=True):
    """Get New Captcha and solve it again
    """
    # Button to refresh the captcha
    refresh_button=browser.find_element_by_id('ContentPlaceHolder1_ImageButton')
    refresh_button.click()
    if display: display_captcha(browser)
    solve_captcha(browser)

# %%
def is_captcha_valid(browser):
    """Check if the page contains the required table
    If solve_captcha worked, it will or else need to solve new captcha
    """
    from selenium.common.exceptions import NoSuchElementException
    try: 
        _ = browser.find_element_by_id('ContentPlaceHolder1_progallships_dgrid')
        #Schedule has been found in page without error
        return True
    except NoSuchElementException: return False

# %% [markdown]
# ### Keep Solving Captcha until correct

# %%
# Try new captchas untill correct prediction ;)
for i in range(100):
    if is_captcha_valid(browser): break #break out of for loop
    solve_captcha_again(browser, display=True)
    from time import sleep
    sleep(1)
# Out:
# OCR Prediction:  142U2
# OCR Prediction:  WyWL
# OCR Prediction:  BIWIVE
# OCR Prediction:  Swls
# OCR Prediction:  2R87Z
# OCR Prediction:  T7Z4R7

# %% [markdown]
# ### Save the page to html

# %%
with open('../Lakport_schedule.html', 'w') as f:
    f.write(browser.page_source)

# %% [markdown]
# ### Showing the read timetable from saved html

# %%
pd.read_html('../Lakport_schedule.html', header=0)[0]
# Out:
#           Date                                      Amindivi      Arabian Sea  \
# 0   10/03/2019                             Mangalore - 13:30    Kochi - 12:20
# 1   11/03/2019  Amini - 09:00Kadmat - 13:00Kavaratti - 17:00  Minicoy - 16:00
# 2   12/03/2019                             Mangalore - 09:00    Kochi - 10:00
# 3   13/03/2019                                           NaN              NaN
# 4   14/03/2019                             Mangalore - 16:00              NaN
# 5   15/03/2019    Bitra - 09:00Chetlat - 14:00Kiltan - 18:00              NaN
# 6   16/03/2019                             Mangalore - 06:00              NaN
# 7   17/03/2019                                           NaN              NaN
# 8   18/03/2019                                           NaN              NaN
# 9   19/03/2019                                           NaN              NaN
# 10  20/03/2019                                           NaN              NaN
# 11  21/03/2019                                           NaN    Kochi - 13:00
# 12  22/03/2019                                           NaN  Minicoy - 15:00
# 13  23/03/2019                                           NaN    Kochi - 07:00
# 14  24/03/2019                                           NaN    Kochi - 13:00
# 15  25/03/2019                                           NaN  Minicoy - 15:00
# 16  26/03/2019                                           NaN    Kochi - 07:00
# 17  27/03/2019                                           NaN              NaN
#
#     Bharat Seema                                        Corals  \
# 0            NaN                                           NaN
# 1            NaN                                           NaN
# 2            NaN                                           NaN
# 3            NaN                                 Kochi - 13:00
# 4            NaN               Kavaratti - 10:00Agatti - 17:00
# 5            NaN    Kiltan - 09:00Chetlat - 11:30Bitra - 16:00
# 6            NaN                                 Kochi - 10:00
# 7            NaN                                           NaN
# 8            NaN                                 Kochi - 13:00
# 9            NaN  Kavaratti - 09:00Amini - 14:00Kadmat - 18:00
# 10           NaN                Kalpeni - 10:00Androth - 18:00
# 11           NaN                                 Kochi - 07:00
# 12           NaN                                           NaN
# 13           NaN                                 Kochi - 13:00
# 14           NaN    Kiltan - 10:00Chetlat - 14:00Bitra - 18:00
# 15           NaN               Agatti - 10:00Kavaratti - 18:00
# 16           NaN                                 Kochi - 09:00
# 17           NaN                                           NaN
#
#                                            Kavaratti  \
# 0                                                NaN
# 1                                      Kochi - 13:00
# 2   Kavaratti - 10:00Agatti - 14:00Kavaratti - 18:00
# 3                                    Minicoy - 16:00
# 4      Kalpeni - 09:00Androth - 13:00Kalpeni - 18:00
# 5                                      Kochi - 07:30
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
#
#                             Lagoons  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                     Kochi - 12:00
# 5   Agatti - 10:00Kavaratti - 18:00
# 6                     Kochi - 10:00
# 7                               NaN
# 8                               NaN
# 9                     Kochi - 13:00
# 10                  Minicoy - 17:00
# 11   Kalpeni - 10:00Androth - 18:30
# 12                    Kochi - 07:00
# 13                              NaN
# 14                    Kochi - 17:00
# 15   Androth - 10:00Kalpeni - 18:00
# 16                    Kochi - 07:00
# 17                              NaN
#
#                                  Lakshadweep Sea  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                  Kochi - 13:00
# 4   Kadmat - 09:00Amini - 12:00Kavaratti - 17:00
# 5                                  Kochi - 10:00
# 6                                            NaN
# 7                                  Kochi - 13:00
# 8                                Minicoy - 15:00
# 9                                  Kochi - 07:00
# 10                                           NaN
# 11                                 Kochi - 12:00
# 12               Agatti - 10:00Kavaratti - 18:00
# 13                                 Kochi - 09:00
# 14                                           NaN
# 15                                 Kochi - 13:00
# 16  Kavaratti - 09:00Amini - 14:00Kadmat - 18:00
# 17                                 Kochi - 10:00
#
#                            Minicoy
# 0                              NaN
# 1                              NaN
# 2                  Beypore - 17:00
# 3   Androth - 10:00Kalpeni - 17:00
# 4                  Beypore - 07:00
# 5                              NaN
# 6                  Beypore - 13:00
# 7      Amini - 10:00Kadmat - 14:00
# 8                  Beypore - 08:00
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
